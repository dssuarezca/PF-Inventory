# %% [markdown]
# ### importamos la librerias que vamos a necesitar

# %%
#en primer instancia importamos las librerias necesarias para poder trabajar con los datos, en este caso utilizamos pandas para poder leer el archivo csv 
# y poder realizar diferentes operaciones al dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
#leemos el archivo csv y lo almacenamos en un dataframe
df_inventario_inicial = pd.read_csv("F:\Documentos\PF Inventory\BegInvFINAL12312016.csv")
df_inventario_inicial["startDate"] = pd.to_datetime(df_inventario_inicial["startDate"])
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1875035477.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df_inventario_inicial = pd.read_csv("F:\Documentos\PF Inventory\BegInvFINAL12312016.csv")

# %%
#leemos el archivo csv y lo almacenamos en un dataframe
df_inventario_final = pd.read_csv("F:\Documentos\PF Inventory\data clean\Inventario_final_2016_clean.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\846641781.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df_inventario_final = pd.read_csv("F:\Documentos\PF Inventory\data clean\Inventario_final_2016_clean.csv")

# %% [markdown]
# ### generamos los gráficos del inventario inicial

# %%
# Seleccionar los 20 productos de mayor valor
top20 = df_inventario_inicial.sort_values("Precio", ascending=False).head(20)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 8
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Graficar
plt.figure(figsize=(12,6))
sns.barplot(data=top20, x="Precio", y="Descripción", palette=colors)  

plt.title("Top 8 productos con mayor valor", fontsize=14)
plt.xlabel("Precio")
plt.ylabel("Producto")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\3584638593.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top20, x="Precio", y="Descripción", palette=colors)

# %%
# Agrupamos por productos para saber el stock total por producto 
productos_top = (
    df_inventario_inicial.groupby("Descripción")["Stock"]
      .sum()
      .sort_values(ascending=False)
      .head(20)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="Stock",
    y="Descripción",
    palette=colors
)
plt.title("Top 20 Productos con mayor stock")
plt.xlabel("Stock")
plt.ylabel("Description")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\560071538.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Agrupamos por ciudades para saber el stock total por ciudad 
productos_top = (
    df_inventario_inicial.groupby("Ciudad")["Stock"]
      .sum()
      .sort_values(ascending=False)
      .head(20)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="Stock",
    y="Ciudad",
    palette=colors
)
plt.title("Top 20 ciudades con mayor stock")
plt.xlabel("Stock")
plt.ylabel("City")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1685399822.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_inventario_inicial.columns = ["ID Inventario", "Tienda", "Ciudad", "Marca", "Descripción", "Volumen", "Stock", "Precio", "Fecha Inventario"]

# %% [markdown]
# ### generamos los gráficos del inventario final

# %%
# Seleccionar los 20 productos de mayor valor
top20 = df_inventario_final.sort_values("Precio Unitario", ascending=False).head(20)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 8
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Graficar
plt.figure(figsize=(12,6))
sns.barplot(data=top20, x="Precio Unitario", y="Descripción", palette=colors)

plt.title("Top 8 productos con mayor valor", fontsize=14)
plt.xlabel("Precio")
plt.ylabel("Producto")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\3547932128.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top20, x="Precio Unitario", y="Descripción", palette=colors)

# %%
# Agrupamos por productos para saber el stock total por producto 
productos_top = (
    df_inventario_final.groupby("Descripción")["Stock"]
      .sum()
      .sort_values(ascending=False)
      .head(20)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="Stock",
    y="Descripción",
    palette=colors
)
plt.title("Top 20 Productos con mayor stock")
plt.xlabel("Stock")
plt.ylabel("Descripción")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1438942114.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Agrupamos por productos para saber el stock total por producto 
productos_top = (
    df_inventario_final.groupby("Ciudad")["Stock"]
      .sum()
      .sort_values(ascending=False)
      .head(20)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="Stock",
    y="Ciudad",
    palette=colors
)
plt.title("Top 20 ciudades con mayor stock")
plt.xlabel("Stock")
plt.ylabel("Ciudad")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1543805346.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### unimos los dos graficos para saber que producto tuvo mayor demanda

# %%
# Unir ambas tablas por producto
df_inventariogeneral = pd.merge(df_inventario_inicial, df_inventario_final, on=["Descripción", "Tienda"])

# %% [markdown]
# ### calculamos el producto mas demandado

# %%
#calculamos la demanda
df_inventariogeneral["demanda"] = df_inventariogeneral["Stock_x"] - df_inventariogeneral["Stock_y"]

# Agrupar por producto y sumar la demanda
demanda_por_producto = df_inventariogeneral.groupby("Descripción")["demanda"].sum().reset_index()

# Ordenar de mayor a menor demanda
demanda_por_producto = demanda_por_producto.sort_values(by="demanda", ascending=False)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

#graficamos
plt.figure(figsize=(10,6))
sns.barplot(data=demanda_por_producto.head(20), 
            x="demanda", 
            y="Descripción", 
            palette=colors)

plt.title("Top 20 productos con mayor demanda", fontsize=14)
plt.xlabel("Demanda total")
plt.ylabel("Producto")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1301409633.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=demanda_por_producto.head(20),

# %% [markdown]
# ### calculamos las tiendas mas demandadas

# %%
# Agrupar por producto y sumar la demanda
demanda_por_tienda = df_inventariogeneral.groupby("Ciudad_x")["demanda"].sum().reset_index()

# Ordenar de mayor a menor demanda
demanda_por_tienda = demanda_por_tienda.sort_values(by="demanda", ascending=False)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 20
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

#graficamos
plt.figure(figsize=(10,6))
sns.barplot(data=demanda_por_tienda.head(20), 
            x="demanda", 
            y="Ciudad_x", 
            palette=colors)

plt.title("Top 20 tiendas con mayor demanda", fontsize=14)
plt.xlabel("Demanda total")
plt.ylabel("Ciudad")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\661320392.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=demanda_por_tienda.head(20),

# %%
#leemos el archivo csv y lo almacenamos en un dataframe
df_factura_compras = pd.read_csv("F:\Documentos\PF Inventory\data clean\ComprasconFactura_2016_clean.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\689200187.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df_factura_compras = pd.read_csv("F:\Documentos\PF Inventory\data clean\ComprasconFactura_2016_clean.csv")

# %%
# Contar cuántos aprobados y no aprobados 
conteo = df_factura_compras["Estado"].value_counts()

# Crear gráfico de barras
plt.figure(figsize=(6,4))
conteo.plot(kind="bar", color=["#1417BEDA", "#13A1B4C6"])
plt.title("Productos aprobados vs no aprobados")
plt.xlabel("Estado de aprobación")
plt.ylabel("Cantidad de productos")
plt.xticks(rotation=0)
plt.show()

# %%
# 2. Agrupar por proveedor y estado de aprobación, sumando el total
grouped = df_factura_compras.groupby(["Vendedor", "Estado"])["Total"].sum().reset_index()

# 3. Pivotear para tener columnas separadas (Aprobado vs No aprobado)
pivot = grouped.pivot(index="Vendedor", columns="Estado", values="Total").fillna(0)

# 4. Ordenar por el total mayor (suma de ambas columnas) y quedarnos con los top 10
pivot["TotalGeneral"] = pivot.sum(axis=1)
pivot_top10 = pivot.sort_values("TotalGeneral", ascending=False).head(10)

# 5. Graficar columnas agrupadas
pivot_top10.drop(columns="TotalGeneral").plot(
    kind="bar", 
    color=["#1417BEDA", "#13A1B4C6"],
    figsize=(12,6)
)

plt.title("Top 10 Proveedores en compras")
plt.ylabel("$ Total")
plt.xlabel("Proveedor")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Estado")
plt.tight_layout()
plt.show()

# %%
# 2. Agrupar por proveedor y estado de aprobación, sumando el total
grouped = df_factura_compras.groupby(["Vendedor", "Estado"])["Cantidad"].sum().reset_index()

# 3. Pivotear para tener columnas separadas (Aprobado vs No aprobado)
pivot = grouped.pivot(index="Vendedor", columns="Estado", values="Cantidad").fillna(0)

# 4. Ordenar por el total mayor (suma de ambas columnas) y quedarnos con los top 10
pivot["TotalGeneral"] = pivot.sum(axis=1)
pivot_top10 = pivot.sort_values("TotalGeneral", ascending=False).head(10)

# 5. Graficar columnas agrupadas
pivot_top10.drop(columns="TotalGeneral").plot(
    kind="bar", 
    color=["#1417BEDA", "#13A1B4C6"],
    figsize=(12,6)
)

plt.title("Top 10 Proveedores compras en cantidad")
plt.ylabel("Cantidad")
plt.xlabel("Proveedor")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Estado")
plt.tight_layout()
plt.show()

# %%
#leemos el archivo csv y lo almacenamos en un dataframe
df_compras_finales = pd.read_csv("F:\Documentos\PF Inventory\data clean\comprasfinales.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\402047672.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df_compras_finales = pd.read_csv("F:\Documentos\PF Inventory\data clean\comprasfinales.csv")

# %%
# cambiamos los nombres de las columnas para que coincidan
df_compras_finales.columns = ["Id_inventario", "Tienda", "Marca", "Descripción", "Volumen", "Id_vendedor", "Vendedor", "Orden_compra", "Fecha_orden", "Fecha_recepcion", "Fecha_factura", "Fecha_pago", "Fecha_compra", "Cantidad", "Total", "Clasificación"]

# %%
# Unir ambas tablas por ponumber
df_POnumber = pd.merge(df_factura_compras, df_compras_finales, on=["Orden_compra"])

# %%
# Contar cuántas veces aparece cada proveedor
top_proveedores = df_POnumber["Vendedor_y"].value_counts().head(10)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 10
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Crear gráfico de barras
plt.figure(figsize=(12,6))
bars = plt.bar(top_proveedores.index, top_proveedores.values, color=colors)

# Etiquetas
plt.title("Top 10 Proveedores mas frecuentes", fontsize=14)
plt.xlabel("Proveedor")
plt.ylabel("frecuencia")
plt.xticks(rotation=45, ha="right")

# Mostrar valores arriba de las barras
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, 
             bar.get_height(), 
             f'{bar.get_height():,.0f}', 
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
top_productos = df_compras_finales.groupby("Descripción")["Cantidad"].sum().nlargest(10)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 10
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

top_productos.plot(kind="bar", figsize=(12,6), color=colors)
plt.title("Top 10 productos más comprados por cantidad")
plt.ylabel("Unidades vendidas")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
#leemos el archivo csv y lo almacenamos en un dataframe
df_ventas_finales = pd.read_csv("F:\ \Documentos\PF Inventory\data clean\\ventas finales.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\1658508248.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df_ventas_finales = pd.read_csv("F:\\Documentos\PF Inventory\data clean\\ventas finales.csv")

# %%
# vamos a calcular el valor total

# %%
# Agrupamos por cantidad de productos para saber cual es el pedido mas vendido 
productos_top = (
    df_ventas_finales.groupby("description")["salesquantity"]
      .sum()
      .sort_values(ascending=False)
      .head(15)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 15
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="description",
    y="salesquantity",
    palette=colors
)
plt.title("Top 15 ciudades con mayor cantidad solicitada")
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\3233218173.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
#calculamos el total de venta por producto
df_ventas_finales["Total_venta"] = df_ventas_finales["excisetax"]*df_ventas_finales["salesquantity"]+df_ventas_finales["salesdollars"]

# %%
# Agrupamos por cantidad de productos para saber cual es el pedido mas vendido 
productos_top = (
    df_ventas_finales.groupby("description")["Total_venta"]
      .sum()
      .sort_values(ascending=False)
      .head(15)
      .reset_index()
)

# Crear colormap desde azul oscuro hasta verde celeste
cmap = LinearSegmentedColormap.from_list("azul_verde", ["#0033cc", "#33cccc"])

n = 15
# Generar n colores del colormap
colors = [cmap(i/(n-1)) for i in range(n)]

# Gráfico
plt.figure(figsize=(10,6))
sns.barplot(
    data=productos_top,
    x="description",
    y="Total_venta",
    palette=colors
)
plt.title("Top 15 productos mas costosos")
plt.xlabel("Producto")
plt.ylabel("Valor Total")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# C:\Users\dssua\AppData\Local\Temp\ipykernel_12276\514970966.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
